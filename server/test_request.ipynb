# %%
import requests


url = "http://127.0.0.1:8000/conversation_model"
#url = "http://:8000/conversation_model"
#url = "http://:8000/conversation_model"

data = {
    "id_user": "alps1248@gmail.com",
    "select_user": "민혁",
    "start_user": "2025. 04. 26. 22-04-57",
    "input_user": "테스트 중... 테스트 중..."
}


response = requests.post(url, json=data)

if response.status_code == 200:
    print(f"AI: {response.json()["response"]}")
else:
    print(f"Error: {response.status_code}")
# Out:
# AI: 잉? 계속 테스트 중이야? 🧐 뭔가 엄청 중요한 걸 테스트하는 건가 봐! 😉
