# %%
import requests


url = "http://127.0.0.1:8000/conversation_model"

data = {
    "input_user": "아이고 사장 진짜 왜 그럴까 나 대신 화풀이 해줘 사장 이름 붙여서"
}

response = requests.post(url, json=data)


if response.status_code == 200:
    print("AI:", response.json()['response'])
else:
    print(f"Error: {response.status_code}")
# Out:
# AI: 김현민 사장님 진짜 왜 그래! 😤 너무하네! 내가 대신 화 풀어줄게! 😡 아오! 🤬
